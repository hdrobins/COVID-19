# %%
import matplotlib.pyplot as plt
import numpy
import pandas

# %% [markdown]
# # Confirmed COVID-19 cases
# ## LATAM vs EUROPE evolution
#
# ### Data from https://github.com/CSSEGISandData/COVID-19
#
# 2019 Novel Coronavirus COVID-19 (2019-nCoV) Data Repository by Johns Hopkins CSSE
# This is the data repository for the 2019 Novel Coronavirus Visual Dashboard operated by the Johns Hopkins University Center for Systems Science and Engineering (JHU CSSE). Also, Supported by ESRI Living Atlas Team and the Johns Hopkins University Applied Physics Lab (JHU APL).

# %%
confirmed = pandas.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv')

# %%
country = confirmed.groupby('Country/Region', as_index=False).sum()
country.drop('Lat', axis=1, inplace=True)
country.drop('Long', axis=1, inplace=True)

# %%
country.head()
# Out:
#         Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0          Afghanistan        0        0        0        0        0        0
# 1              Albania        0        0        0        0        0        0
# 2              Algeria        0        0        0        0        0        0
# 3              Andorra        0        0        0        0        0        0
# 4  Antigua and Barbuda        0        0        0        0        0        0
#
#    1/28/20  1/29/20  1/30/20  ...  3/8/20  3/9/20  3/10/20  3/11/20  3/12/20  \
# 0        0        0        0  ...       4       4        5        7        7
# 1        0        0        0  ...       0       2       10       12       23
# 2        0        0        0  ...      19      20       20       20       24
# 3        0        0        0  ...       1       1        1        1        1
# 4        0        0        0  ...       0       0        0        0        0
#
# ...

# %%
latam   = country.loc[country['Country/Region'].isin(['Argentina','Brazil','Chile','Bolivia','Colombia','Uruguay','Paraguay','Peru','Venezuela','Ecuador'])]
europe  = country.loc[country['Country/Region'].isin(['Italy','Iran','Spain'])]

compare = country.loc[country['Country/Region'].isin(['Argentina','Brazil','Spain','Chile','Italy'])]

# %% [markdown]
# # 2020-03-17 Report
#
# ## LATAM
#
# ### Brazil, Chile and Peru are growing in exponential model
# ### Argentina growing is controlled
# ### Colombia is initializing growing
#
#
# ## EUROPE
#
# ### Italia is growing in exponential model
# ### Iran growing is controlled
# ### Spain is initializing growing in exponential model

# %%
latam.set_index("Country/Region").T.plot(figsize=(15,5))
plt.title('LATAM COVID-19 Confirmed')
plt.show()


europe.set_index("Country/Region").T.plot(figsize=(15,5))
plt.title('EUROPE COVID-19 Confirmed')
plt.show()

# %%
latam
# Out:
#     Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 5        Argentina        0        0        0        0        0        0
# 18         Bolivia        0        0        0        0        0        0
# 20          Brazil        0        0        0        0        0        0
# 28           Chile        0        0        0        0        0        0
# 30        Colombia        0        0        0        0        0        0
# 42         Ecuador        0        0        0        0        0        0
# 107       Paraguay        0        0        0        0        0        0
# 108           Peru        0        0        0        0        0        0
# 148        Uruguay        0        0        0        0        0        0
# 150      Venezuela        0        0        0        0        0        0
#
#      1/28/20  1/29/20  1/30/20  ...  3/8/20  3/9/20  3/10/20  3/11/20  \
# 5          0        0        0  ...      12      12       17       19
# ...

# %%
europe
# Out:
#     Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 66            Iran        0        0        0        0        0        0
# 70           Italy        0        0        0        0        0        0
# 129          Spain        0        0        0        0        0        0
#
#      1/28/20  1/29/20  1/30/20  ...  3/8/20  3/9/20  3/10/20  3/11/20  \
# 66         0        0        0  ...    6566    7161     8042     9000
# 70         0        0        0  ...    7375    9172    10149    12462
# 129        0        0        0  ...     673    1073     1695     2277
#
#      3/12/20  3/13/20  3/14/20  3/15/20  3/16/20  3/17/20
# 66     10075    11364    12729    13938    14991    16169
# 70     12462    17660    21157    24747    27980    31506
# 129     2277     5232     6391     7798     9942    11748
#
# [3 rows x 57 columns]

# %%
compare
# Out:
#     Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 5        Argentina        0        0        0        0        0        0
# 20          Brazil        0        0        0        0        0        0
# 28           Chile        0        0        0        0        0        0
# 70           Italy        0        0        0        0        0        0
# 129          Spain        0        0        0        0        0        0
#
#      1/28/20  1/29/20  1/30/20  ...  3/8/20  3/9/20  3/10/20  3/11/20  \
# 5          0        0        0  ...      12      12       17       19
# 20         0        0        0  ...      20      25       31       38
# 28         0        0        0  ...       8       8       13       23
# 70         0        0        0  ...    7375    9172    10149    12462
# 129        0        0        0  ...     673    1073     1695     2277
#
#      3/12/20  3/13/20  3/14/20  3/15/20  3/16/20  3/17/20
# ...

# %%
df = pandas.DataFrame(columns=['Pais','dia01','dia02','dia03','dia04','dia05','dia06','dia07','dia08','dia09','dia10','dia11','dia12','dia13','dia14','dia15'])
nRow=0
data=[]

for index, row in compare.iterrows():
    nRow=nRow+1
    nCol=0
    nPos=0
    vec = [row['Country/Region'],numpy.nan,numpy.nan,numpy.nan,numpy.nan,numpy.nan,numpy.nan,numpy.nan,numpy.nan,numpy.nan,numpy.nan,numpy.nan,numpy.nan,numpy.nan,numpy.nan,numpy.nan]
    
    for (columnName, columnData) in compare.iteritems():
        nCol=nCol+1
        if nCol>1 and columnData.values[nRow-1]>0 and nPos<15:
           nPos=nPos+1
           vec[nPos]=columnData.values[nRow-1]
            
    
    data.append(vec)

df = pandas.DataFrame(data, columns = ['Country','day01','day02','day03','day04','day05','day06','day07','day08','day09','day10','day11','day12','day13','day14','day15']) 
df.set_index('Country')
# Out:
#            day01  day02  day03  day04  day05  day06  day07  day08  day09  \
# Country
# Argentina      1      1      1      2      8     12     12     17     19
# Brazil         1      1      1      2      2      2      2      4      4
# Chile          1      1      4      4      4      8      8     13     23
# Italy          2      2      2      2      2      2      2      3      3
# Spain          1      1      1      1      1      1      1      1      2
#
#            day10  day11  day12  day13  day14  day15
# Country
# Argentina     19     31     34     45     56     68
# Brazil        13     13     20     25     31     38
# Chile         23     43     61     74    155    201
# Italy          3      3      3      3      3      3
# Spain          2      2      2      2      2      2

# %%
df.set_index("Country").T.plot(figsize=(6,5))
plt.suptitle('REGIONS COVID-19 Confirmed')
plt.title('15 días desde el 1er caso confirmado en Argentina')

plt.show()

# %%
nRow=0
data=[]

for index, row in compare.iterrows():
    nRow=nRow+1
    nCol=0
    nPos=0
    vec = [row['Country/Region'],numpy.nan,numpy.nan,numpy.nan,numpy.nan,numpy.nan,numpy.nan,numpy.nan,numpy.nan,numpy.nan,numpy.nan,numpy.nan,numpy.nan,numpy.nan,numpy.nan,numpy.nan,numpy.nan]
    
    for (columnName, columnData) in compare.iteritems():
        nCol=nCol+1
        vec[16]=columnData.values[nRow-1]

        if nCol>1 and columnData.values[nRow-1]>0 and nPos<15:
            if (row['Country/Region'] == 'Italy' or row['Country/Region']=='Spain') and columnData.values[nRow-1] > 5: 
                nPos=nPos+1
                vec[nPos]=columnData.values[nRow-1]
            if (row['Country/Region'] != 'Italy' and row['Country/Region']!='Spain'):    
                nPos=nPos+1
                vec[nPos]=columnData.values[nRow-1]

    data.append(vec)

df = pandas.DataFrame(data, columns = ['Country','day01','day02','day03','day04','day05','day06','day07','day08','day09','day10','day11','day12','day13','day14','day15','today']) 
df.set_index('Country')
# Out:
#            day01  day02  day03  day04  day05  day06  day07  day08  day09  \
# Country
# Argentina      1      1      1      2      8     12     12     17     19
# Brazil         1      1      1      2      2      2      2      4      4
# Chile          1      1      4      4      4      8      8     13     23
# Italy         20     62    155    229    322    453    655    888   1128
# Spain          6     13     15     32     45     84    120    165    222
#
#            day10  day11  day12  day13  day14  day15  today
# Country
# Argentina     19     31     34     45     56     68     68
# Brazil        13     13     20     25     31     38    321
# Chile         23     43     61     74    155    201    201
# Italy       1694   2036   2502   3089   3858   4636  31506
# Spain        259    400    500    673   1073   1695  11748

# %% [markdown]
# El gráfico muestra la evolución del virus a partir de que se presentó el 1er. caso en LATAM y en el caso de España e Italia a partir de que hubieron más de 5 casos, ya que desde ese momento los registros activos crecieron considerablemente

# %%
df.drop('today', axis=1, inplace=True)

# %%
df.set_index("Country").T.plot(figsize=(6,5))
plt.suptitle('REGIONS COVID-19 Confirmed')
plt.title('Italia y España a partir de cuando superaron 5 casos confirmados')
plt.show()
