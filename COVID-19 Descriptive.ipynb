# %%
import matplotlib.pyplot as plt
import numpy
import pandas

# %% [markdown]
# # Confirmed COVID-19 cases
# ## LATAM vs EUROPE evolution
#
# ### Data from https://github.com/CSSEGISandData/COVID-19
#
# 2019 Novel Coronavirus COVID-19 (2019-nCoV) Data Repository by Johns Hopkins CSSE
# This is the data repository for the 2019 Novel Coronavirus Visual Dashboard operated by the Johns Hopkins University Center for Systems Science and Engineering (JHU CSSE). Also, Supported by ESRI Living Atlas Team and the Johns Hopkins University Applied Physics Lab (JHU APL).

# %%
confirmed = pandas.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv')

# %%
country = confirmed.groupby('Country/Region', as_index=False).sum()

# %%
country.head()
# Out:
#         Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0          Afghanistan  33.0000  65.0000        0        0        0        0
# 1              Albania  41.1533  20.1683        0        0        0        0
# 2              Algeria  28.0339   1.6596        0        0        0        0
# 3              Andorra  42.5063   1.5218        0        0        0        0
# 4  Antigua and Barbuda  17.0608 -61.7964        0        0        0        0
#
#    1/26/20  1/27/20  1/28/20  ...  3/7/20  3/8/20  3/9/20  3/10/20  3/11/20  \
# 0        0        0        0  ...       1       4       4        5        7
# 1        0        0        0  ...       0       0       2       10       12
# 2        0        0        0  ...      17      19      20       20       20
# 3        0        0        0  ...       1       1       1        1        1
# 4        0        0        0  ...       0       0       0        0        0
#
#    3/12/20  3/13/20  3/14/20  3/15/20  3/16/20
# 0        7        7       11       16       21
# 1       23       33       38       42       51
# 2       24       26       37       48       54
# 3        1        1        1        1        2
# 4        0        1        1        1        1
#
# [5 rows x 58 columns]

# %%
latam  = country.loc[country['Country/Region'].isin(['Argentina','Brazil','Chile','Bolivia','Colombia','Uruguay','Paraguay','Peru','Venezuela'])]
europe = country.loc[country['Country/Region'].isin(['Italy','Iran','Spain'])]

# %%
latam.drop('Lat', axis=1, inplace=True)
latam.drop('Long', axis=1, inplace=True)

europe.drop('Lat', axis=1, inplace=True)
europe.drop('Long', axis=1, inplace=True)
# Out:
# /home/drobins/miniconda3/envs/diplodatos/lib/python3.6/site-packages/pandas/core/frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %% [markdown]
# # 2020-03-16 Report
#
# ## LATAM
#
# ### Brazil, Chile and Peru are growing in exponential model
# ### Argentina growing is controlled
# ### Colombia is initializing growing
#
#
# ## EUROPE
#
# ### Italia is growing in exponential model
# ### Iran growing is controlled
# ### Spain is initializing growing in exponential model

# %%
latam.set_index("Country/Region").T.plot(figsize=(15,5))
plt.title('LATAM COVID-19 Confirmed')
plt.Axes.autoscale_view
plt.show()


europe.set_index("Country/Region").T.plot(figsize=(15,5))
plt.title('EUROPE COVID-19 Confirmed')
plt.Axes.autoscale_view
plt.show()

# %%
latam
# Out:
#     Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 5        Argentina        0        0        0        0        0        0
# 17         Bolivia        0        0        0        0        0        0
# 19          Brazil        0        0        0        0        0        0
# 27           Chile        0        0        0        0        0        0
# 29        Colombia        0        0        0        0        0        0
# 109       Paraguay        0        0        0        0        0        0
# 110           Peru        0        0        0        0        0        0
# 151        Uruguay        0        0        0        0        0        0
# 153      Venezuela        0        0        0        0        0        0
#
#      1/28/20  1/29/20  1/30/20  ...  3/7/20  3/8/20  3/9/20  3/10/20  3/11/20  \
# 5          0        0        0  ...       8      12      12       17       19
# 17         0        0        0  ...       0       0       0        0        2
# 19         0        0        0  ...      13      20      25       31       38
# 27         0        0        0  ...       4       8       8       13       23
# 29         0        0        0  ...       1       1       1        3        9
# 109        0        0        0  ...       0       1       1        1        5
# 110        0        0        0  ...       1       6       7       11       11
# 151        0        0        0  ...       0       0       0        0        0
# 153        0        0        0  ...       0       0       0        0        0
#
#      3/12/20  3/13/20  3/14/20  3/15/20  3/16/20
# 5         19       31       34       45       56
# 17         2        3       10       10       11
# 19        52      151      151      162      200
# 27        23       43       61       74      155
# 29         9       13       22       34       54
# 109        5        6        6        6        8
# 110       15       28       38       43       86
# 151        0        0        4        4        8
# 153        0        0        2       10       17
#
# [9 rows x 56 columns]

# %%
europe
# Out:
#     Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 68            Iran        0        0        0        0        0        0
# 72           Italy        0        0        0        0        0        0
# 133          Spain        0        0        0        0        0        0
#
#      1/28/20  1/29/20  1/30/20  ...  3/7/20  3/8/20  3/9/20  3/10/20  3/11/20  \
# 68         0        0        0  ...    5823    6566    7161     8042     9000
# 72         0        0        0  ...    5883    7375    9172    10149    12462
# 133        0        0        0  ...     500     673    1073     1695     2277
#
#      3/12/20  3/13/20  3/14/20  3/15/20  3/16/20
# 68     10075    11364    12729    13938    14991
# 72     12462    17660    21157    24747    27980
# 133     2277     5232     6391     7798     9942
#
# [3 rows x 56 columns]
